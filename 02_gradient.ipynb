# %% [markdown]
# # Gradient method
#
# We can solve regression problem with **"Gradient descent"** to optimize the loss function. In this notebook, I will use MSE as a loss function.

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression

# %%
X = np.array([1, 1, 1, 2, 2, 3, 3, 4, 4, 5, 6]).reshape((-1, 1))
y = np.array([1, 1.5, 1.2, 3, 4, 4, 5, 6, 7, 8, 9]).reshape((-1, 1))

X.shape, y.shape
# Out:
# ((11, 1), (11, 1))

# %%
plt.scatter(X, y, label="actual")
plt.legend()

# %%
model = LinearRegression().fit(X, y)

# %%
plt.scatter(X, y, label="actual")
plt.plot(X, model.predict(X), color='red', label="predict")
plt.legend()
